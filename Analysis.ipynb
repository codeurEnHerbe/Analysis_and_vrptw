# %%
import pandas as pd

# Load the data from Excel
excel_path = 'rev_by_cli.xlsx'
revenues_df = pd.read_excel(excel_path, 'SS23')

# Display the first few rows of the dataframe to understand its structure
revenues_df
# Out:
#             Unnamed: 0  GM         Boutique                  Ville  \
# 0                  NaN NaN              NaN                    NaN
# 1          13 BISNANCY NaN           13 BIS                  NANCY
# 2            5PMNANTES NaN              5PM                 NANTES
# 3   ADG STUDIOGRENOBLE NaN       ADG STUDIO               GRENOBLE
# 4        ANATOLIAARLES NaN         ANATOLIA                  ARLES
# 5        ANATOLIANIMES NaN         ANATOLIA                  NIMES
# 6      ATALANTEANTIBES NaN         ATALANTE                ANTIBES
# 7                  NaN NaN              NaN                    NaN
# 8                  NaN NaN              NaN    Total CA par marque
# 9                  NaN NaN              NaN         Btq par marque
# 10                 NaN NaN              NaN      Btq par marque GM
# 11                 NaN NaN              NaN          Moyen par btq
# 12                 NaN NaN              NaN  Moyen par btq hors GM
# ...

# %%
rev_values = revenues_df.iloc[1:7, 6:10]
rev_values = rev_values.replace('#ERROR!', 0).astype(int)
# Out:
# C:\Users\Rafael\AppData\Local\Temp\ipykernel_23212\2939198390.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   rev_values = rev_values.replace('#ERROR!', 0).astype(int)

# %% [markdown]
# Sum up revenues for each brand

# %%
res = zip(uniq_stores, rev_values.sum(axis=1))

# %%
list(res)
# Out:
# [('13 BISNANCY, 13 BIS', 10000),
#  ('5PMNANTES, 5PM', 10000),
#  ('ADG STUDIOGRENOBLE, ADG STUDIO', 30000),
#  ('ANATOLIAARLES, ANATOLIA', 10000),
#  ('ANATOLIANIMES, ANATOLIA', 10000),
#  ('ATALANTEANTIBES, ATALANTE', 20000)]
